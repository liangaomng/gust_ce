# %%
**average:0.10953606440064807-node1
***std:0.049749596890776286
node2**average:0.11247394035259882
***std:0.015905921277493018
**average:0.14725707694888115-node3
***std:0.044545454317330285
--node4**average:0.21591544697682064
***std:0.10492504764908783
--node5 **average:0.35937742044528326
***std:0.16941416409500254

# %%
import matplotlib.pyplot as plt

# Node data
nodes = ['Node 1', 'Node 2', 'Node 3', 'Node 4', 'Node 5']
averages = [0.10953606440064807, 0.11247394035259882, 0.14725707694888115, 0.21591544697682064, 0.35937742044528326]
std_devs = [0.049749596890776286, 0.015905921277493018, 0.044545454317330285, 0.10492504764908783, 0.16941416409500254]

# Creating the bar plot with error bars
plt.figure(figsize=(10, 6))
plt.bar(nodes, averages, yerr=std_devs, capsize=5, color='skyblue')
plt.xlabel('Nodes')
plt.ylabel('Average Value')
plt.title('Average and Standard Deviation for Each Node')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
